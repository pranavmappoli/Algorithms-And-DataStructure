# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
cd drive/My Drive/ml/Regression/
cd Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('Position_Salaries.csv')

# %%
X=data.iloc[:,1].values
y=data.iloc[:,2].values

# %%
from sklearn.preprocessing import PolynomialFeatures
obj=PolynomialFeatures(degree=6)

# %%
X_new=obj.fit_transform(X.reshape(-1, 1))

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_new,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_grid=np.arange(min(X),max(X),0.1)

# %%
plt.scatter(X,y)
plt.plot(X_grid,regressor.predict(obj.fit_transform(X_grid.reshape(-1, 1))))

# %%
#prediction a value

a=np.array((6,4))
regressor.predict(obj.fit_transform(a.reshape(-1, 1)))
# Out:
# array([143275.05827509,  94632.86713282])
