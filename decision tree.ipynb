# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
cd drive/My Drive/ml/Regression/

# %%
cd Decision Tree Regression

# %%
data=pd.read_csv("Position_Salaries.csv")
X=data.iloc[:,1].values
y=data.iloc[:,2].values

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(10)

# %%
regressor.fit(X.reshape(-1, 1),y.reshape(-1, 1))

# %%
a=np.array(5).reshape(-1,1)
regressor.predict(a)
# Out:
# array([95000.])

# %%
xnew=np.arange(min(X),max(X),0.1)
plt.scatter(X,y)
plt.plot(xnew.reshape(-1, 1),regressor.predict(xnew.reshape(-1, 1)))

# %%
plt.scatter(X,y)

# %%
data
